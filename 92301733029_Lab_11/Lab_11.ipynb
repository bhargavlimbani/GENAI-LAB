# %% [markdown]
# ### Bhargav Limbani
# 92301733029

# %% [markdown]
# ##**Chunking**

# %%
# !pip install langchain langchain-community langchain-text-splitter pypdf pymupdf

# %%
# !pip install langchain langchain-community
# Out:
# ...
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader
# Out:
# /tmp/ipykernel_645/3177898484.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyMuPDFLoader

# %%
# !pip install pypdf pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.9/382.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 61.0 MB/s eta 0:00:00
# ...

# %%
text=PyMuPDFLoader("/content/FIFA World Cup 2026.pdf")

# %%
text_load=text.load()

# %%
text_load
# Out:
# [Document(metadata={'producer': 'WeasyPrint 68.0', 'creator': 'ChatGPT', 'creationdate': '', 'source': '/content/FIFA World Cup 2026.pdf', 'file_path': '/content/FIFA World Cup 2026.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': 'FIFA World Cup 2026', 'author': 'ChatGPT Canvas', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='FIFA World Cup 2026: The Biggest World Cup in\nHistory\nThe FIFA World Cup 2026 marks a historic new chapter in international football. Co-hosted by Canada,\nMexico and the United States, the tournament is the first FIFA World Cup to feature 48 teams, expanding\nthe competition from the traditional 32-team format. With 104 matches scheduled across 16 host cities, the\n2026 tournament promises to be one of the largest sporting events ever organized. \nA New Era for the World Cup\nThe 2026 World Cup represents a major change in the structure of the competition. Instead of eight groups
# ...

# %%
from langchain_text_splitters  import CharacterTextSplitter

# %%
splitter=CharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=50,
)

# %%
chunks=splitter.split_documents(text_load)

# %%
len(chunks)
# Out:
# 3

# %%
for i in chunks:
  print(i.page_content)
  print("--------------------------------------------------------")
# Out:
# FIFA World Cup 2026: The Biggest World Cup in
# History
# The FIFA World Cup 2026 marks a historic new chapter in international football. Co-hosted by Canada,
# Mexico and the United States, the tournament is the first FIFA World Cup to feature 48 teams, expanding
# the competition from the traditional 32-team format. With 104 matches scheduled across 16 host cities, the
# 2026 tournament promises to be one of the largest sporting events ever organized.
# A New Era for the World Cup
# The 2026 World Cup represents a major change in the structure of the competition. Instead of eight groups
# of four teams, the tournament has 12 groups of four teams. Each team plays three group-stage matches.
# The top two teams from each group, along with the eight best third-placed teams, advance to a new
# Round of 32. From there, the tournament follows the traditional knockout structure: Round of 16, quarter-
# finals, semi-finals and final.
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
splitter1=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=50,
    )

# %%
chunks1=splitter1.split_documents(text_load)

# %%
for i in chunks1:
  print(i.page_content)
  print("--------------------------------------------------------")
# Out:
# FIFA World Cup 2026: The Biggest World Cup in
# History
# --------------------------------------------------------
# The FIFA World Cup 2026 marks a historic new chapter in international football. Co-hosted by
# --------------------------------------------------------
# chapter in international football. Co-hosted by Canada,
# --------------------------------------------------------
# Mexico and the United States, the tournament is the first FIFA World Cup to feature 48 teams,
# --------------------------------------------------------
# is the first FIFA World Cup to feature 48 teams, expanding
# --------------------------------------------------------
# the competition from the traditional 32-team format. With 104 matches scheduled across 16 host
# --------------------------------------------------------
# format. With 104 matches scheduled across 16 host cities, the
# --------------------------------------------------------
# ...

# %%
from langchain_text_splitters import TokenTextSplitter

# %%
splitter=TokenTextSplitter(
    chunk_size=100,
    chunk_overlap=50,
    )

# %%
chunks2=splitter.split_documents(text_load)

# %%
for i in chunks1:
  print(i.page_content)
  print("--------------------------------------------------------")
# Out:
# FIFA World Cup 2026: The Biggest World Cup in
# History
# --------------------------------------------------------
# The FIFA World Cup 2026 marks a historic new chapter in international football. Co-hosted by
# --------------------------------------------------------
# chapter in international football. Co-hosted by Canada,
# --------------------------------------------------------
# Mexico and the United States, the tournament is the first FIFA World Cup to feature 48 teams,
# --------------------------------------------------------
# is the first FIFA World Cup to feature 48 teams, expanding
# --------------------------------------------------------
# the competition from the traditional 32-team format. With 104 matches scheduled across 16 host
# --------------------------------------------------------
# format. With 104 matches scheduled across 16 host cities, the
# --------------------------------------------------------
# ...

# %%
from langchain_text_splitters import SentenceTransformersTokenTextSplitter

# %%
splitter3=SentenceTransformersTokenTextSplitter(
    chunk_size=100,
    chunk_overlap=50,
    )
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  438MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# ...

# %%
chunks=splitter.split_documents(text_load)

# %%
for i in chunks:
  print(i.page_content)
  print("--------------------------------------------------------")
# Out:
# FIFA World Cup 2026: The Biggest World Cup in
# History
# The FIFA World Cup 2026 marks a historic new chapter in international football. Co-hosted by Canada,
# Mexico and the United States, the tournament is the first FIFA World Cup to feature 48 teams, expanding
# the competition from the traditional 32-team format. With 104 matches scheduled across 16 host cities, the
# 2026 tournament promises to be one of the largest sporting events ever organized.
# A New
# --------------------------------------------------------
#  FIFA World Cup to feature 48 teams, expanding
# the competition from the traditional 32-team format. With 104 matches scheduled across 16 host cities, the
# 2026 tournament promises to be one of the largest sporting events ever organized.
# A New Era for the World Cup
# The 2026 World Cup represents a major change in the structure of the competition. Instead of eight groups
# ...
