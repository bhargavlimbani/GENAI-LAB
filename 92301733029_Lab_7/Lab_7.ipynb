# %% [markdown]
# ### Bhargav Limbani
# 92301733029

# %%
# !pip langchain langchain-community
# Out:
# ERROR: unknown command "langchain"

# %%
from langchain_core.prompts import PromptTemplate

# %%
prompt=PromptTemplate(input_variables=["name"], template="tell me the capital of {name}.")

# %%
user_input=input("user:")
final_prompt=prompt.format(name=user_input)
print(final_prompt)
# Out:
# user:india
# tell me the capital of india.

# %%
# !pip install langchain-groq
from langchain_groq import ChatGroq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 1.2 MB/s eta 0:00:00
# ...

# %%
GROQ_API_KEY = "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"

grok_model = ChatGroq( model="llama-3.3-70b-versatile",
                      api_key=GROQ_API_KEY,
                       )

# %%
response=grok_model.invoke(final_prompt)
print(response.content)
# Out:
# The capital of India is New Delhi.
